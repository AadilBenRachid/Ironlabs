# %% [markdown]
# # Challenge 1: Get a Picture

# %%
import requests
import pandas as pd
#from bs4 import BeautifulSoup
#url= 'https://xkcd.com'
#Go to the link https://xkcd.com
#your code
response = requests.get('https://xkcd.com')
#sp = BeautifulSoup(response, "lxml")
#sp
response
# Out:
# <Response [200]>

# %%
response.status_code
# Out:
# 200

# %%
#check the headers
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '3192', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Wed, 09 Nov 2022 10:39:51 GMT', 'ETag': 'W/"636b8377-1f8c"', 'Expires': 'Thu, 10 Nov 2022 02:38:16 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Date': 'Thu, 10 Nov 2022 15:45:50 GMT', 'Age': '52', 'X-Served-By': 'cache-dfw-kdfw8210099-DFW, cache-cdg20781-CDG', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '10, 1', 'X-Timer': 'S1668095150.168441,VS0,VE1', 'Vary': 'Accept-Encoding'}

# %%
#check the headers "Expires" value
response.headers['Expires']
# Out:
# 'Thu, 10 Nov 2022 02:38:16 GMT'

# %%
# Provide all HTML codes
response.content #or response.text
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: Precision vs Accuracy</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<!-- <script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script> -->\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="Precision vs Accuracy">\n<meta property="og:url" content="https://xkcd.com/2696/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/precision_vs_accuracy_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<bod
# ...

# %%
#Get it via API
receive= requests.get("https://imgs.xkcd.com/comics/imho.png")
with open (r'/Users/manu/downloads/image.png','wb') as f:
    f.write(receive.content)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Untitled-1.ipynb Cellule 7 in <cell line: 3>()
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X26sdW50aXRsZWQ%3D?line=0'>1</a> #Get it via API
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X26sdW50aXRsZWQ%3D?line=1'>2</a> receive= requests.get("https://imgs.xkcd.com/comics/imho.png")
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X26sdW50aXRsZWQ%3D?line=2'>3</a> with open (r'/Users/manu/downloads/image.png','wb') as f:
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#X26sdW50aXRsZWQ%3D?line=3'>4</a>     f.write(receive.content)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/manu/downloads/image.png'

# %% [markdown]
# # Challenge 2: Get a password

# %%
import requests 
ploads=requests.get('https://httpbin.org/get')
ploads
print(ploads.text)
print(ploads.url)
# Out:
# {
#   "args": {},
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-636d1d38-3a042f460a13491200aed103"
#   },
#   "origin": "93.26.177.45",
#   "url": "https://httpbin.org/get"
# }
#
# https://httpbin.org/get

# %%
ploads.headers
# Out:
# {'Date': 'Thu, 10 Nov 2022 15:48:08 GMT', 'Content-Type': 'application/json', 'Content-Length': '310', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
#get information from the website => use 'get'
ploads={'things':2,'total':25}
ploads=requests.get('https://httpbin.org/get',params=ploads)
ploads
# Out:
# <Response [200]>

# %%
ploads={'Username':'manu','Password':'adm'}
r=requests.post('https://httpbin.org/post',data=ploads)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "Password": "adm",
#     "Username": "manu"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "26",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-636d1d6a-5b36f45f01a1be916f74fc6c"
#   },
#   "json": null,
#   "origin": "93.26.177.45",
#   "url": "https://httpbin.org/post"
# }

# %%
#send information to the website => so use 'post'
ploads={'Username':'manu','Password':'adm'}
r=requests.post('https://httpbin.org/post',data=ploads)
r_dict= r.json()
print(r_dict['form'])
# Out:
# {'Password': 'adm', 'Username': 'manu'}

# %% [markdown]
# # Challenge 3: Hidden Cold Joke

# %%
response = requests.get('https://api.github.com/search/code?q=.scavengerhunt in:path+repo:ironhack-datalabs/scavenger');
search = response.json()
search
# Out:
# {'total_count': 24,
#  'incomplete_results': False,
#  'items': [{'name': '.0016.scavengerhunt',
#    'path': '47222/.0016.scavengerhunt',
#    'sha': 'f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'url': 'https://api.github.com/repositories/162375181/contents/47222/.0016.scavengerhunt?ref=9308ccc8a4c34c5e3a991ee815222a9691c32476',
#    'git_url': 'https://api.github.com/repositories/162375181/git/blobs/f5cb13223fdc1b11f4cfbbe1694f533b3c579fa0',
#    'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/9308ccc8a4c34c5e3a991ee815222a9691c32476/47222/.0016.scavengerhunt',
#    'repository': {'id': 162375181,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkxNjIzNzUxODE=',
#     'name': 'scavenger',
#     'full_name': 'ironhack-datalabs/scavenger',
#     'private': False,
#     'owner': {'login': 'ironhack-datalabs',
#      'id': 44225188,
#      'node_id': 'MDEyOk9yZ2FuaXphdGlvbjQ0MjI1MTg4',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/44225188?v=4',
# ...

# %%
files = search['items'];
files = sorted(files, key=lambda file: file['name']);

# %%
contents_list = []
headers = {'Accept': 'application/vnd.github.v3.raw', };
headers
# Out:
# {'Accept': 'application/vnd.github.v3.raw'}

# %%
for file in files:
    content_path = ('https://api.github.com/repos/ironhack-datalabs/scavenger/contents/{}').format(file['path']);
    response = requests.get(content_path, headers=headers);
    contents_list.append(response.text);

# %%
print(contents_list)
# Out:
# ['In\n', 'data\n', 'science,\n', '80\n', 'percent\n', 'of\n', 'time\n', 'spent\n', 'is\n', 'preparing\n', 'data,\n', '20\n', 'percent\n', 'of\n', 'time\n', 'is\n', 'spent\n', 'complaining\n', 'about\n', 'the\n', 'need\n', 'to\n', 'prepare\n', 'data.\n']

# %%
clean_contents = [word.strip('\n') for word in contents_list]
joke = " ".join(clean_contents);

# %%
joke
# Out:
# 'In data science, 80 percent of time spent is preparing data, 20 percent of time is spent complaining about the need to prepare data.'

# %% [markdown]
# # Additional Challenge- Fork

# %% [markdown]
# Challange to find in our data-lab repo:
#
# * number of forks
# * number of commits
# * languages used

# %%
#https://api.github.com/users/Ironhack/repos

import json
import requests

#Use the get method to send a request to the JSONPlaceholder API
response = requests.get('https://api.github.com/users/Ironhack/repos')

print(response.status_code)

#print(response.text)

results = response.json()
#print(results)

data = pd.DataFrame(results)
data
#flattened_data = pd.json_normalize(results)
#flattened_data
# Out:
# 200
#           id                           node_id                     name  \
# 0  197550983  MDEwOlJlcG9zaXRvcnkxOTc1NTA5ODM=  alfresco-keycloak-theme
# 1  150108250  MDEwOlJlcG9zaXRvcnkxNTAxMDgyNTA=               canvas-lms
# 2  111009816  MDEwOlJlcG9zaXRvcnkxMTEwMDk4MTY=                generator
# 3   64460430  MDEwOlJlcG9zaXRvcnk2NDQ2MDQzMA==                   hackmd
# 4  154337700  MDEwOlJlcG9zaXRvcnkxNTQzMzc3MDA=          ih-lms-devstack
# 5  144919503  MDEwOlJlcG9zaXRvcnkxNDQ5MTk1MDM=       lab-hello-ironhack
# 6  184281457  MDEwOlJlcG9zaXRvcnkxODQyODE0NTc=                 learn-js
# 7  176717811  MDEwOlJlcG9zaXRvcnkxNzY3MTc4MTE=                  md2oedx
# 8  145679727  MDEwOlJlcG9zaXRvcnkxNDU2Nzk3Mjc=         mern-boilerplate
#
#                           full_name  private  \
# 0  ironhack/alfresco-keycloak-theme    False
# 1               ironhack/canvas-lms    False
# 2                ironhack/generator    False
# 3                   ironhack/hackmd    False
# ...

# %%
data.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %% [markdown]
# # No. of fork

# %%
#No. of fork
print(data.fork.value_counts())
# Out:
# True     8
# False    1
# Name: fork, dtype: int64

# %% [markdown]
# # For find the tha languages in lab_13

# %%
data.language
# Out:
# 0    FreeMarker
# 1          Ruby
# 2    JavaScript
# 3    JavaScript
# 4          TSQL
# 5          None
# 6    JavaScript
# 7    JavaScript
# 8    JavaScript
# Name: language, dtype: object

# %%
data.language.unique()
# Out:
# array(['FreeMarker', 'Ruby', 'JavaScript', 'TSQL', None], dtype=object)

# %% [markdown]
# # No. of commit

# %%
#No. of commit
print(len(data.git_commits_url))
# Out:
# 9

# %%
language_extract=set(i for i in data.language if i != None)
print(language_extract)
# Out:
# {'TSQL', 'JavaScript', 'FreeMarker', 'Ruby'}

# %% [markdown]
# # Get the password

# %%
import requests

r = requests.get('https://httpbin.org/get')

# %%
r
# Out:
# <Response [200]>

# %%
r.headers
# Out:
# {'Date': 'Thu, 10 Nov 2022 16:08:17 GMT', 'Content-Type': 'application/json', 'Content-Length': '310', 'Connection': 'keep-alive', 'Server': 'gunicorn/19.9.0', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true'}

# %%
ploads = {'things1':2,'total1':25}
r = requests.get('https://httpbin.org/get',params= ploads)
print(r.text)
print(r.url)
# Out:
# {
#   "args": {
#     "things1": "2",
#     "total1": "25"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-636d2220-4ba44f8d5316a9a005b5a235"
#   },
#   "origin": "93.26.177.45",
#   "url": "https://httpbin.org/get?things1=2&total1=25"
# }
#
# https://httpbin.org/get?things1=2&total1=25

# %%
pload = {'username' : 'aadil', 'password': 'ben'}
r = requests.post('https://httpbin.org/post', data = pload)
print(r.text)
# Out:
# {
#   "args": {},
#   "data": "",
#   "files": {},
#   "form": {
#     "password": "ben",
#     "username": "aadil"
#   },
#   "headers": {
#     "Accept": "*/*",
#     "Accept-Encoding": "gzip, deflate, br",
#     "Content-Length": "27",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "Host": "httpbin.org",
#     "User-Agent": "python-requests/2.27.1",
#     "X-Amzn-Trace-Id": "Root=1-636d2262-7ed1aff97167b6966c015b52"
#   },
#   "json": null,
#   "origin": "93.26.177.45",
#   "url": "https://httpbin.org/post"
# }

# %%
pload = {'username' : 'aadil', 'password': 'ben'}
r = requests.post('https://httpbin.org/post', data = pload)
r_dictionary = r.json()
print(r_dictionary['form'])
# Out:
# {'password': 'ben', 'username': 'aadil'}
